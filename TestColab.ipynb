# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhairavi-Logic/Test-skills-copilot-codespaces-vscode/blob/main/TestColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: write a code to simulate chaos theory

import matplotlib.pyplot as plt

def logistic_map(r, x):
  return r * x * (1 - x)

# Parameters
r_values = [3.5, 3.7, 3.9, 4.0]  # Different r values for demonstration
x0 = 0.2  # Initial condition
iterations = 100

for r in r_values:
    x_values = [x0]
    for _ in range(iterations):
        x_next = logistic_map(r, x_values[-1])
        x_values.append(x_next)
    plt.plot(x_values[10:], label=f"r = {r}")  # Plot after discarding initial iterations


plt.xlabel("Iteration")
plt.ylabel("x")
plt.title("Logistic Map: Chaos")
plt.legend()
plt.show()
